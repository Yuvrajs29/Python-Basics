# %%
with open('D:\Python\File_Handling\example .txt','r') as file:
    content=file.read()
    print(content)
# Out:
# Hello this is our 5 module on Python learning and we are trying to get back to the path
# DS and DA are the roles .
# having the basic knowledge
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_29680\3557612850.py:1: SyntaxWarning: invalid escape sequence '\P'
#   with open('D:\Python\File_Handling\example .txt','r') as file:

# %%
with open('example.txt', 'w') as file:
    file.write("Hello, this is a test file!")

# %%
with open('example .txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello this is our 5 module on Python learning and we are trying to get back to the path
# DS and DA are the roles .
# having the basic knowledge

# %%
with open('test29.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# gdyuwdbwaouicdhian s
# sdndcoiene
# ncodjnsmc

# %%
#read a file line by line
with open('example .txt','r') as file:
    for line in file:
        print(line)
# Out:
# Hello this is our 5 module on Python learning and we are trying to get back to the path
#
# DS and DA are the roles .
#
# having the basic knowledge

# %%
#read a file line by line
with open('example .txt','r') as file:
    for line in file:
        print(line.strip()) ## strip() to remove the newline character
# Out:
# Hello this is our 5 module on Python learning and we are trying to get back to the path
# DS and DA are the roles .
# having the basic knowledge

# %%
##writing a file
with open('example.txt','w') as file:
    file.write('Hello Data!\n')
    file.write('tis is the new line.')
    ##this will remove the old content and overwrite it

# %%
##write a file(without overwriting)
with open('example.txt','a') as file:
    file.write('Append place taking place.\n')

# %%
##Writing a list of line to a file 
lines=['first line\n','second line \n','third line \n']
with open('example.txt','a') as file:
    file.writelines(lines)
    ##Write a list of lines to stream.

##Line separators are not added, so it is usual for each of the
##lines provided to have a line separator at the end.

# %%
## Binary files
##write
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
##read
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','rb') as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### read the content froma source text file and write to a destinantion text file
### copying a text file

with open('example.txt','r') as source_file:
    content= source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
## read a text file and count the number of lines , words, and characters.
# counting lines, words , and characters in a real line file
def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.strip()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count,word_count,char_count

file_path = 'example.txt'
lines,words,characters = count_text_file(file_path)
print(f'Lines:{lines}, Words:{words}, Characters:{characters}')
# Out:
# Lines:7, Words:190, Characters:199
