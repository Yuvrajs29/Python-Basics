# %%
## if statement = if condition evaluate the condition and execute the block of code within it if the condition is true .

age = 20

if age>=20:
    print("You are eligible for driving ")
# Out:
# You are eligible for driving

# %%
## else = else statement execute the block of code if the condition in if statement is false.

age =  16 

if age>=18:
    print("you are eligible for voting")
else:
    print("you are A minor ")
# Out:
# you are A minor

# %%
## elif = it allows you to check the multiple conditions . it stands for 'else if '

age = 20
if age<13:
    print("You are  a child ") 
elif age<18:
    print("You are a teenager")
else :
    print("You are an adult")
# Out:
# You are an adult

# %%
# Nested conditional statements 
# you can place one or more  if , eilf , or else statement inside  another if,elif or else statements to create nested 
# condition statement .


n = 0
if n<0:
    print("number is negative")
elif n==0:
    print("it is zero")               
elif n%2==0:
    print("It is even")
elif  n%2!=0:
    print("It is odd")
# Out:
# it is zero

# %%
# Practical example

y = 2000
if y%4==0:
    print("it is a leap year")
elif y%100!=0:
    print("it is not a leap year")
elif y%400==0:
    print("it is leap year")
else:
    print("it is not leap year")
# Out:
# it is a leap year
